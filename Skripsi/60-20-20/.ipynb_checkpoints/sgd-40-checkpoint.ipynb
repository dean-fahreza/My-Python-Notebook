# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Preprocessing Data

# %%
from keras_preprocessing.image import ImageDataGenerator

TRAINING_DIR = "train"
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

VALIDATION_DIR = "valid"
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

# %%
train_generator = training_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)
# Out:
# Found 2100 images belonging to 3 classes.
# Found 702 images belonging to 3 classes.

# %% [markdown]
# # Create Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
model = Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])
model.summary()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       6,423,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │           1,539 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,490,147 (24.76 MB)
#  Trainable params: 6,490,147 (24.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import optimizers

# Create the optimizer with the desired learning rate
opt = optimizers.SGD(learning_rate=0.01)

model.compile(loss = 'categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator, 
    epochs = 40,
    validation_data = validation_generator, 
    verbose = 1)
model.save("SGD-40-model.h5")
# Out:
# Epoch 1/40
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 753ms/step - accuracy: 0.3844 - loss: 1.0920 - val_accuracy: 0.3960 - val_loss: 1.0880
# Epoch 2/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 765ms/step - accuracy: 0.4938 - loss: 1.0181 - val_accuracy: 0.3504 - val_loss: 1.3496
# Epoch 3/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 770ms/step - accuracy: 0.5931 - loss: 0.8422 - val_accuracy: 0.3390 - val_loss: 2.1291
# Epoch 4/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 55s 790ms/step - accuracy: 0.4444 - loss: 1.1064 - val_accuracy: 0.3803 - val_loss: 2.2349
# Epoch 5/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 56s 806ms/step - accuracy: 0.6609 - loss: 0.7046 - val_accuracy: 0.4359 - val_loss: 1.7869
# Epoch 6/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 55s 802ms/step - accuracy: 0.6563 - loss: 0.9353 - val_accuracy: 0.5712 - val_loss: 0.8453
# Epoch 7/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 55s 799ms/step - accuracy: 0.8070 - loss: 0.6033 - val_accuracy: 0.4915 - val_loss: 1.1038
# Epoch 8/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 56s 804ms/step - accuracy: 0.8715 - loss: 0.3554 - val_accuracy: 0.7293 - val_loss: 0.5333
# Epoch 9/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 56s 806ms/step - accuracy: 0.8805 - loss: 0.3229 - val_accuracy: 0.6339 - val_loss: 0.8715
# Epoch 10/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 56s 816ms/step - accuracy: 0.9046 - loss: 0.2831 - val_accuracy: 0.4003 - val_loss: 2.0711
# Epoch 11/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 56s 814ms/step - accuracy: 0.9230 - loss: 0.2136 - val_accuracy: 0.7521 - val_loss: 0.5410
# Epoch 12/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 824ms/step - accuracy: 0.9151 - loss: 0.2812 - val_accuracy: 0.4701 - val_loss: 1.8452
# Epoch 13/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 827ms/step - accuracy: 0.9349 - loss: 0.1845 - val_accuracy: 0.5883 - val_loss: 1.0486
# Epoch 14/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 825ms/step - accuracy: 0.9378 - loss: 0.1660 - val_accuracy: 0.5826 - val_loss: 1.0317
# Epoch 15/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 825ms/step - accuracy: 0.9440 - loss: 0.1674 - val_accuracy: 0.5570 - val_loss: 1.1615
# Epoch 16/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 58s 832ms/step - accuracy: 0.9464 - loss: 0.1546 - val_accuracy: 0.6439 - val_loss: 0.8520
# Epoch 17/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9500 - loss: 0.1431 - val_accuracy: 0.5670 - val_loss: 1.1039
# Epoch 18/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9655 - loss: 0.1024 - val_accuracy: 0.6595 - val_loss: 0.8872
# Epoch 19/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 949ms/step - accuracy: 0.9598 - loss: 0.1188 - val_accuracy: 0.5627 - val_loss: 1.4286
# Epoch 20/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 989ms/step - accuracy: 0.9666 - loss: 0.1078 - val_accuracy: 0.4772 - val_loss: 2.0064
# Epoch 21/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 939ms/step - accuracy: 0.9677 - loss: 0.1022 - val_accuracy: 0.6168 - val_loss: 0.9468
# Epoch 22/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 985ms/step - accuracy: 0.9407 - loss: 0.1939 - val_accuracy: 0.6396 - val_loss: 0.9682
# Epoch 23/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 910ms/step - accuracy: 0.9798 - loss: 0.0749 - val_accuracy: 0.5157 - val_loss: 1.6824
# Epoch 24/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 943ms/step - accuracy: 0.9534 - loss: 0.1474 - val_accuracy: 0.6709 - val_loss: 0.8670
# Epoch 25/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 917ms/step - accuracy: 0.9797 - loss: 0.0728 - val_accuracy: 0.5840 - val_loss: 1.2849
# Epoch 26/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 972ms/step - accuracy: 0.9676 - loss: 0.0812 - val_accuracy: 0.5954 - val_loss: 1.2122
# Epoch 27/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 988ms/step - accuracy: 0.9701 - loss: 0.0895 - val_accuracy: 0.5897 - val_loss: 1.2759
# Epoch 28/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 988ms/step - accuracy: 0.9727 - loss: 0.0742 - val_accuracy: 0.5627 - val_loss: 1.3242
# Epoch 29/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9826 - loss: 0.0595 - val_accuracy: 0.5926 - val_loss: 1.1728
# Epoch 30/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 946ms/step - accuracy: 0.9799 - loss: 0.0623 - val_accuracy: 0.5641 - val_loss: 1.5405
# Epoch 31/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9788 - loss: 0.0642 - val_accuracy: 0.5613 - val_loss: 1.4729
# Epoch 32/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9745 - loss: 0.0678 - val_accuracy: 0.6538 - val_loss: 1.0906
# Epoch 33/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 910ms/step - accuracy: 0.9792 - loss: 0.0595 - val_accuracy: 0.6168 - val_loss: 1.2661
# Epoch 34/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9825 - loss: 0.0844 - val_accuracy: 0.6111 - val_loss: 1.2432
# Epoch 35/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9824 - loss: 0.0515 - val_accuracy: 0.6083 - val_loss: 1.1295
# Epoch 36/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9864 - loss: 0.0483 - val_accuracy: 0.6211 - val_loss: 1.2323
# Epoch 37/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9558 - loss: 0.1448 - val_accuracy: 0.5584 - val_loss: 1.6728
# Epoch 38/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 988ms/step - accuracy: 0.9857 - loss: 0.0478 - val_accuracy: 0.6481 - val_loss: 1.1261
# Epoch 39/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 982ms/step - accuracy: 0.9843 - loss: 0.0428 - val_accuracy: 0.6040 - val_loss: 1.5062
# Epoch 40/40
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 911ms/step - accuracy: 0.9838 - loss: 0.0521 - val_accuracy: 0.6111 - val_loss: 1.2765
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, label='Akurasi Training')
plt.plot(epochs, val_acc, label='Akurasi Validation')
plt.title('Akurasi Training dan Validation Model 60:20 SGD epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/60-20-20/results/Hasil akurasi model SGD 60-20 epochs 40.jpg')
plt.figure()

plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss Training dan validation Model 60:20 SGD epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/60-20-20/results/Hasil loss model SGD 60-20 epochs 40.jpg')
plt.figure()

plt.show()

# %% [markdown]
# # Testing Model

# %%
from tensorflow import keras
model = keras.models.load_model('C:/Coding/pengujian/60-20-20/SGD-40-model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import math

TEST_DIR = "test"
test_datagen = ImageDataGenerator(
    rescale = 1.0/255
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(256,256),
    batch_size=32,
    shuffle=False,
    class_mode='categorical')

test_steps_per_epoch = math.ceil(test_generator.samples / test_generator.batch_size)
# Out:
# Found 702 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator, steps=test_steps_per_epoch)

predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = test_generator.class_indices.keys()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step

# %%
import os
from os import listdir
import pandas as pd

sehat = os.listdir("C:/Coding/pengujian/60-20-20/test/healthy")
septoria = os.listdir("C:/Coding/pengujian/60-20-20/test/septoria")
stripe_rust = os.listdir("C:/Coding/pengujian/60-20-20/test/stripe_rust")

data = sehat + septoria + stripe_rust

df = pd.DataFrame()
df['Nama File']=data
df['true_classes']=true_classes
df['Predicted_classes']=predicted_classes
df.to_csv('C:/Coding/pengujian/60-20-20/results/Hasil pengujian model SGD-40.csv')

# %% [markdown]
# # Find Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.figure(figsize=(10,7))
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  plt.yticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  #fmt = '.2f'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j]), horizontalalignment= "center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()

plt.savefig('C:/Coding/pengujian/60-20-20/results/Confusion Matrix Model SGD 60-20 epochs 40.jpg')
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix Klasifikasi Penyakit Daun Gandum')

# %% [markdown]
# # Find Performances Metrices

# %%
from sklearn import metrics
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
target_names = ['Healthy', 'Septoria', 'Stripe Rust']
report = metrics.classification_report(true_classes, predicted_classes, target_names=target_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.74      0.85       234
#     Septoria       0.98      0.98      0.98       234
#  Stripe Rust       0.79      1.00      0.88       234
#
#     accuracy                           0.91       702
#    macro avg       0.92      0.91      0.90       702
# weighted avg       0.92      0.91      0.90       702
