# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Preprocessing Data

# %%
from keras_preprocessing.image import ImageDataGenerator

TRAINING_DIR = "train"
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

VALIDATION_DIR = "valid"
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

# %%
train_generator = training_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)
# Out:
# Found 2802 images belonging to 3 classes.
# Found 351 images belonging to 3 classes.

# %% [markdown]
# # Create Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
model = Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])
model.summary()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       6,423,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │           1,539 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,490,147 (24.76 MB)
#  Trainable params: 6,490,147 (24.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import optimizers

# Create the optimizer with the desired learning rate
opt = optimizers.SGD(learning_rate=0.01)

model.compile(loss = 'categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator, 
    epochs = 20,
    validation_data = validation_generator, 
    verbose = 1)
model.save("SGD-20-model.h5")
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 78s 871ms/step - accuracy: 0.3638 - loss: 1.0936 - val_accuracy: 0.6638 - val_loss: 1.0880
# Epoch 2/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.5275 - loss: 0.9919 - val_accuracy: 0.3704 - val_loss: 1.0981
# Epoch 3/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 943ms/step - accuracy: 0.6144 - loss: 0.8162 - val_accuracy: 0.4957 - val_loss: 1.1540
# Epoch 4/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 80s 912ms/step - accuracy: 0.7066 - loss: 0.6510 - val_accuracy: 0.6667 - val_loss: 1.4183
# Epoch 5/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 919ms/step - accuracy: 0.8026 - loss: 0.4942 - val_accuracy: 0.6040 - val_loss: 1.2681
# Epoch 6/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 79s 891ms/step - accuracy: 0.8014 - loss: 0.4997 - val_accuracy: 0.6781 - val_loss: 0.9365
# Epoch 7/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 85s 964ms/step - accuracy: 0.8703 - loss: 0.3602 - val_accuracy: 0.8063 - val_loss: 0.6028
# Epoch 8/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 914ms/step - accuracy: 0.8826 - loss: 0.3113 - val_accuracy: 0.5926 - val_loss: 0.9107
# Epoch 9/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 76s 860ms/step - accuracy: 0.8950 - loss: 0.2770 - val_accuracy: 0.6467 - val_loss: 1.7317
# Epoch 10/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 987ms/step - accuracy: 0.9323 - loss: 0.1984 - val_accuracy: 0.6125 - val_loss: 1.1180
# Epoch 11/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.9115 - loss: 0.2426 - val_accuracy: 0.5926 - val_loss: 1.3015
# Epoch 12/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 955ms/step - accuracy: 0.9309 - loss: 0.1735 - val_accuracy: 0.6439 - val_loss: 0.9690
# Epoch 13/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 991ms/step - accuracy: 0.9477 - loss: 0.1577 - val_accuracy: 0.5983 - val_loss: 1.2908
# Epoch 14/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 934ms/step - accuracy: 0.9512 - loss: 0.1415 - val_accuracy: 0.8120 - val_loss: 1.1205
# Epoch 15/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9425 - loss: 0.1578 - val_accuracy: 0.6211 - val_loss: 2.1582
# Epoch 16/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9422 - loss: 0.1596 - val_accuracy: 0.6325 - val_loss: 0.8357
# Epoch 17/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9640 - loss: 0.1162 - val_accuracy: 0.6610 - val_loss: 1.5576
# Epoch 18/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 952ms/step - accuracy: 0.9647 - loss: 0.1040 - val_accuracy: 0.6410 - val_loss: 1.3265
# Epoch 19/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9778 - loss: 0.0708 - val_accuracy: 0.6553 - val_loss: 0.9894
# Epoch 20/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9771 - loss: 0.0893 - val_accuracy: 0.6097 - val_loss: 2.0222
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, label='Akurasi Training')
plt.plot(epochs, val_acc, label='Akurasi Validation')
plt.title('Akurasi Training dan Validation Model 80:10 SGD epochs 20')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/80-10-10/results/Hasil akurasi model SGD 80-10 epochs 20.jpg')
plt.figure()

plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss Training dan validation Model 80:10 SGD epochs 20')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/80-10-10/results/Hasil loss model SGD 80-10 epochs 20.jpg')
plt.figure()

plt.show()

# %% [markdown]
# # Testing Model

# %%
from tensorflow import keras
model = keras.models.load_model('C:/Coding/pengujian/80-10-10/SGD-20-model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import math

TEST_DIR = "test"
test_datagen = ImageDataGenerator(
    rescale = 1.0/255
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(256,256),
    batch_size=32,
    shuffle=False,
    class_mode='categorical')

test_steps_per_epoch = math.ceil(test_generator.samples / test_generator.batch_size)
# Out:
# Found 351 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator, steps=test_steps_per_epoch)

predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = test_generator.class_indices.keys()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step

# %%
import os
from os import listdir
import pandas as pd

sehat = os.listdir("C:/Coding/pengujian/80-10-10/test/healthy")
septoria = os.listdir("C:/Coding/pengujian/80-10-10/test/septoria")
stripe_rust = os.listdir("C:/Coding/pengujian/80-10-10/test/stripe_rust")

data = sehat + septoria + stripe_rust

df = pd.DataFrame()
df['Nama File']=data
df['true_classes']=true_classes
df['Predicted_classes']=predicted_classes
df.to_csv('C:/Coding/pengujian/80-10-10/results/Hasil pengujian model SGD-20.csv')

# %% [markdown]
# # Find Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.figure(figsize=(10,7))
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  plt.yticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  #fmt = '.2f'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j]), horizontalalignment= "center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()

cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix Klasifikasi Penyakit Daun Gandum')

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('C:/Coding/pengujian/80-10-10/results/Confusion Matrix Model SGD 80-10 epochs 20.png', dpi=100)

# %% [markdown]
# # Find Performances Metrices

# %%
from sklearn import metrics
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
target_names = ['Healthy', 'Septoria', 'Stripe Rust']
report = metrics.classification_report(true_classes, predicted_classes, target_names=target_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.69      0.82       117
#     Septoria       1.00      0.56      0.72       117
#  Stripe Rust       0.57      1.00      0.73       117
#
#     accuracy                           0.75       351
#    macro avg       0.86      0.75      0.76       351
# weighted avg       0.86      0.75      0.76       351
