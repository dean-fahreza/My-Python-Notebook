# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Preprocessing Data

# %%
from keras_preprocessing.image import ImageDataGenerator

TRAINING_DIR = "train"
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

VALIDATION_DIR = "valid"
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

# %%
train_generator = training_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)
# Out:
# Found 2802 images belonging to 3 classes.
# Found 351 images belonging to 3 classes.

# %% [markdown]
# # Create Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
model = Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])
model.summary()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       6,423,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │           1,539 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,490,147 (24.76 MB)
#  Trainable params: 6,490,147 (24.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import optimizers

# Create the optimizer with the desired learning rate
opt = optimizers.SGD(learning_rate=0.01)

model.compile(loss = 'categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator, 
    epochs = 40,
    validation_data = validation_generator, 
    verbose = 1)
model.save("SGD-40-model.h5")
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.3673 - loss: 1.0928 - val_accuracy: 0.1225 - val_loss: 1.0681
# Epoch 2/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 948ms/step - accuracy: 0.5423 - loss: 0.9973 - val_accuracy: 0.3761 - val_loss: 1.0260
# Epoch 3/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 75s 847ms/step - accuracy: 0.6330 - loss: 0.7787 - val_accuracy: 0.4900 - val_loss: 1.4463
# Epoch 4/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.7011 - loss: 0.6516 - val_accuracy: 0.4957 - val_loss: 1.1686
# Epoch 5/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.7619 - loss: 0.6115 - val_accuracy: 0.7550 - val_loss: 0.5298
# Epoch 6/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 944ms/step - accuracy: 0.8746 - loss: 0.3563 - val_accuracy: 0.7692 - val_loss: 0.5024
# Epoch 7/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 84s 950ms/step - accuracy: 0.8905 - loss: 0.2912 - val_accuracy: 0.6439 - val_loss: 0.6158
# Epoch 8/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.8987 - loss: 0.2425 - val_accuracy: 0.6524 - val_loss: 1.0091
# Epoch 9/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.9204 - loss: 0.2233 - val_accuracy: 0.7123 - val_loss: 0.4887
# Epoch 10/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 104s 1s/step - accuracy: 0.9289 - loss: 0.1825 - val_accuracy: 0.6467 - val_loss: 0.9783
# Epoch 11/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.8254 - loss: 0.5116 - val_accuracy: 0.8319 - val_loss: 0.4879
# Epoch 12/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.9434 - loss: 0.1752 - val_accuracy: 0.6638 - val_loss: 1.3714
# Epoch 13/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9697 - loss: 0.0930 - val_accuracy: 0.6667 - val_loss: 1.4581
# Epoch 14/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.9546 - loss: 0.1585 - val_accuracy: 0.6667 - val_loss: 1.3201
# Epoch 15/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 986ms/step - accuracy: 0.9695 - loss: 0.0778 - val_accuracy: 0.6581 - val_loss: 0.8327
# Epoch 16/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9690 - loss: 0.0842 - val_accuracy: 0.6667 - val_loss: 1.8529
# Epoch 17/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 984ms/step - accuracy: 0.9820 - loss: 0.0621 - val_accuracy: 0.6667 - val_loss: 2.2265
# Epoch 18/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9821 - loss: 0.0620 - val_accuracy: 0.6581 - val_loss: 1.4568
# Epoch 19/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9821 - loss: 0.0599 - val_accuracy: 0.6553 - val_loss: 2.2278
# Epoch 20/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.9788 - loss: 0.0591 - val_accuracy: 0.6610 - val_loss: 2.4778
# Epoch 21/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.9805 - loss: 0.0462 - val_accuracy: 0.6667 - val_loss: 3.3004
# Epoch 22/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.9840 - loss: 0.0528 - val_accuracy: 0.6667 - val_loss: 3.2030
# Epoch 23/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.9885 - loss: 0.0371 - val_accuracy: 0.6211 - val_loss: 2.0964
# Epoch 24/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.9809 - loss: 0.0600 - val_accuracy: 0.6467 - val_loss: 2.9671
# Epoch 25/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.9848 - loss: 0.0417 - val_accuracy: 0.6097 - val_loss: 2.2122
# Epoch 26/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.9878 - loss: 0.0442 - val_accuracy: 0.6667 - val_loss: 3.9684
# Epoch 27/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9869 - loss: 0.0369 - val_accuracy: 0.6382 - val_loss: 3.4833
# Epoch 28/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 983ms/step - accuracy: 0.9780 - loss: 0.0606 - val_accuracy: 0.6410 - val_loss: 3.0051
# Epoch 29/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.9833 - loss: 0.0423 - val_accuracy: 0.6410 - val_loss: 3.2387
# Epoch 30/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.9927 - loss: 0.0273 - val_accuracy: 0.6296 - val_loss: 2.9449
# Epoch 31/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.9781 - loss: 0.0609 - val_accuracy: 0.6268 - val_loss: 3.1502
# Epoch 32/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.9918 - loss: 0.0268 - val_accuracy: 0.6296 - val_loss: 2.9021
# Epoch 33/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 83s 948ms/step - accuracy: 0.9868 - loss: 0.0536 - val_accuracy: 0.6097 - val_loss: 1.2054
# Epoch 34/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9083 - loss: 0.2494 - val_accuracy: 0.5783 - val_loss: 2.2681
# Epoch 35/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9419 - loss: 0.1479 - val_accuracy: 0.6182 - val_loss: 1.8259
# Epoch 36/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 87s 987ms/step - accuracy: 0.9862 - loss: 0.0457 - val_accuracy: 0.6125 - val_loss: 2.0911
# Epoch 37/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 88s 996ms/step - accuracy: 0.9873 - loss: 0.0403 - val_accuracy: 0.6410 - val_loss: 2.5039
# Epoch 38/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9916 - loss: 0.0290 - val_accuracy: 0.6154 - val_loss: 2.5113
# Epoch 39/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.9920 - loss: 0.0282 - val_accuracy: 0.6553 - val_loss: 2.5897
# Epoch 40/40
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 88s 994ms/step - accuracy: 0.9851 - loss: 0.0348 - val_accuracy: 0.6553 - val_loss: 3.3898
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, label='Akurasi Training')
plt.plot(epochs, val_acc, label='Akurasi Validation')
plt.title('Akurasi Training dan Validation Model 80:10 SGD epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/80-10-10/results/Hasil akurasi model SGD 80-10 epochs 40.jpg')
plt.figure()

plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss Training dan validation Model 80:10 SGD epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/80-10-10/results/Hasil loss model SGD 80-10 epochs 40.jpg')
plt.figure()

plt.show()

# %% [markdown]
# # Testing Model

# %%
from tensorflow import keras
model = keras.models.load_model('C:/Coding/pengujian/80-10-10/SGD-40-model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import math

TEST_DIR = "test"
test_datagen = ImageDataGenerator(
    rescale = 1.0/255
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(256,256),
    batch_size=32,
    shuffle=False,
    class_mode='categorical')

test_steps_per_epoch = math.ceil(test_generator.samples / test_generator.batch_size)
# Out:
# Found 351 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator, steps=test_steps_per_epoch)

predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = test_generator.class_indices.keys()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 389ms/step

# %%
import os
from os import listdir
import pandas as pd

sehat = os.listdir("C:/Coding/pengujian/80-10-10/test/healthy")
septoria = os.listdir("C:/Coding/pengujian/80-10-10/test/septoria")
stripe_rust = os.listdir("C:/Coding/pengujian/80-10-10/test/stripe_rust")

data = sehat + septoria + stripe_rust

df = pd.DataFrame()
df['Nama File']=data
df['true_classes']=true_classes
df['Predicted_classes']=predicted_classes
df.to_csv('C:/Coding/pengujian/80-10-10/results/Hasil pengujian model SGD-40.csv')

# %% [markdown]
# # Find Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.figure(figsize=(10,7))
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  plt.yticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  #fmt = '.2f'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j]), horizontalalignment= "center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()

cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix Klasifikasi Penyakit Daun Gandum')

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('C:/Coding/pengujian/80-10-10/results/Confusion Matrix Model SGD 80-10 epochs 40.png', dpi=100)

# %% [markdown]
# # Find Performances Metrices

# %%
from sklearn import metrics
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
target_names = ['Healthy', 'Septoria', 'Stripe Rust']
report = metrics.classification_report(true_classes, predicted_classes, target_names=target_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.59      0.74       117
#     Septoria       1.00      0.56      0.72       117
#  Stripe Rust       0.54      1.00      0.70       117
#
#     accuracy                           0.72       351
#    macro avg       0.85      0.72      0.72       351
# weighted avg       0.85      0.72      0.72       351
