# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Preprocessing Data

# %%
from keras_preprocessing.image import ImageDataGenerator

TRAINING_DIR = "train"
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

VALIDATION_DIR = "valid"
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

# %%
train_generator = training_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)
# Out:
# Found 2454 images belonging to 3 classes.
# Found 525 images belonging to 3 classes.

# %% [markdown]
# # Create Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
model = Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])
model.summary()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       6,423,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │           1,539 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,490,147 (24.76 MB)
#  Trainable params: 6,490,147 (24.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import optimizers

# Create the optimizer with the desired learning rate
opt = optimizers.SGD(learning_rate=0.01)

model.compile(loss = 'categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator, 
    epochs = 40,
    validation_data = validation_generator, 
    verbose = 1)
model.save("SGD-40-model.h5")
# Out:
# Epoch 1/40
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 60s 736ms/step - accuracy: 0.3440 - loss: 1.0962 - val_accuracy: 0.4286 - val_loss: 1.0909
# Epoch 2/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 705ms/step - accuracy: 0.5232 - loss: 1.0346 - val_accuracy: 0.6629 - val_loss: 1.0920
# Epoch 3/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 58s 726ms/step - accuracy: 0.5396 - loss: 0.9386 - val_accuracy: 0.3771 - val_loss: 1.4534
# Epoch 4/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 736ms/step - accuracy: 0.6328 - loss: 0.8124 - val_accuracy: 0.6495 - val_loss: 0.9844
# Epoch 5/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 756ms/step - accuracy: 0.7143 - loss: 0.6569 - val_accuracy: 0.6419 - val_loss: 1.0405
# Epoch 6/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 756ms/step - accuracy: 0.7169 - loss: 0.6795 - val_accuracy: 0.5829 - val_loss: 1.1038
# Epoch 7/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 760ms/step - accuracy: 0.7713 - loss: 0.5268 - val_accuracy: 0.5638 - val_loss: 0.9580
# Epoch 8/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 60s 750ms/step - accuracy: 0.8277 - loss: 0.3989 - val_accuracy: 0.6971 - val_loss: 0.7619
# Epoch 9/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 755ms/step - accuracy: 0.8775 - loss: 0.3168 - val_accuracy: 0.7676 - val_loss: 0.4998
# Epoch 10/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 60s 749ms/step - accuracy: 0.8974 - loss: 0.2693 - val_accuracy: 0.7657 - val_loss: 0.6108
# Epoch 11/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 758ms/step - accuracy: 0.9425 - loss: 0.1621 - val_accuracy: 0.7657 - val_loss: 0.5619
# Epoch 12/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 755ms/step - accuracy: 0.9450 - loss: 0.1600 - val_accuracy: 0.7467 - val_loss: 1.4001
# Epoch 13/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 763ms/step - accuracy: 0.9567 - loss: 0.1129 - val_accuracy: 0.7524 - val_loss: 1.2184
# Epoch 14/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 755ms/step - accuracy: 0.9732 - loss: 0.0848 - val_accuracy: 0.7390 - val_loss: 1.8009
# Epoch 15/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 766ms/step - accuracy: 0.9567 - loss: 0.1489 - val_accuracy: 0.7429 - val_loss: 0.9988
# Epoch 16/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 763ms/step - accuracy: 0.9772 - loss: 0.0755 - val_accuracy: 0.7562 - val_loss: 1.7279
# Epoch 17/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 768ms/step - accuracy: 0.9700 - loss: 0.0845 - val_accuracy: 0.7619 - val_loss: 1.2858
# Epoch 18/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 762ms/step - accuracy: 0.9804 - loss: 0.0636 - val_accuracy: 0.7448 - val_loss: 1.4370
# Epoch 19/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 773ms/step - accuracy: 0.9783 - loss: 0.0673 - val_accuracy: 0.7619 - val_loss: 1.6655
# Epoch 20/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 770ms/step - accuracy: 0.9863 - loss: 0.0488 - val_accuracy: 0.7410 - val_loss: 1.6123
# Epoch 21/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 770ms/step - accuracy: 0.9787 - loss: 0.0563 - val_accuracy: 0.6838 - val_loss: 2.0730
# Epoch 22/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 767ms/step - accuracy: 0.9831 - loss: 0.0492 - val_accuracy: 0.7390 - val_loss: 1.7138
# Epoch 23/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 772ms/step - accuracy: 0.9882 - loss: 0.0449 - val_accuracy: 0.7467 - val_loss: 1.6380
# Epoch 24/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 776ms/step - accuracy: 0.9815 - loss: 0.0540 - val_accuracy: 0.7562 - val_loss: 0.6590
# Epoch 25/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 770ms/step - accuracy: 0.9768 - loss: 0.0869 - val_accuracy: 0.7619 - val_loss: 1.1809
# Epoch 26/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 62s 772ms/step - accuracy: 0.9856 - loss: 0.0429 - val_accuracy: 0.7619 - val_loss: 1.3244
# Epoch 27/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 63s 781ms/step - accuracy: 0.9914 - loss: 0.0304 - val_accuracy: 0.7410 - val_loss: 1.3002
# Epoch 28/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 79s 983ms/step - accuracy: 0.9879 - loss: 0.0351 - val_accuracy: 0.7619 - val_loss: 1.8656
# Epoch 29/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9927 - loss: 0.0318 - val_accuracy: 0.7619 - val_loss: 1.8932
# Epoch 30/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 73s 909ms/step - accuracy: 0.9817 - loss: 0.0489 - val_accuracy: 0.7524 - val_loss: 2.3694
# Epoch 31/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 928ms/step - accuracy: 0.9930 - loss: 0.0246 - val_accuracy: 0.7619 - val_loss: 1.7031
# Epoch 32/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 66s 821ms/step - accuracy: 0.9852 - loss: 0.0401 - val_accuracy: 0.7619 - val_loss: 1.4518
# Epoch 33/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 66s 823ms/step - accuracy: 0.9886 - loss: 0.0298 - val_accuracy: 0.7619 - val_loss: 1.5373
# Epoch 34/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 69s 860ms/step - accuracy: 0.9932 - loss: 0.0294 - val_accuracy: 0.7619 - val_loss: 2.0444
# Epoch 35/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 75s 938ms/step - accuracy: 0.9870 - loss: 0.0251 - val_accuracy: 0.7619 - val_loss: 1.5384
# Epoch 36/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 68s 845ms/step - accuracy: 0.9963 - loss: 0.0170 - val_accuracy: 0.7524 - val_loss: 1.9983
# Epoch 37/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 929ms/step - accuracy: 0.9918 - loss: 0.0190 - val_accuracy: 0.7619 - val_loss: 1.9666
# Epoch 38/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9936 - loss: 0.0205 - val_accuracy: 0.7600 - val_loss: 2.5424
# Epoch 39/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 946ms/step - accuracy: 0.9934 - loss: 0.0162 - val_accuracy: 0.7619 - val_loss: 1.7307
# Epoch 40/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 954ms/step - accuracy: 0.9968 - loss: 0.0127 - val_accuracy: 0.7619 - val_loss: 2.3184
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, label='Akurasi Training')
plt.plot(epochs, val_acc, label='Akurasi Validation')
plt.title('Akurasi Training dan Validation Model 70:15 SGD epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/70-15-15/results/Hasil akurasi model SGD 70-15 epochs 40.jpg')
plt.figure()

plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss Training dan validation Model 70:15 SGD epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/70-15-15/results/Hasil loss model SGD 70-15 epochs 40.jpg')
plt.figure()

plt.show()

# %% [markdown]
# # Testing Model

# %%
from tensorflow import keras
model = keras.models.load_model('C:/Coding/pengujian/60-20-20/SGD-40-model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import math

TEST_DIR = "test"
test_datagen = ImageDataGenerator(
    rescale = 1.0/255
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(256,256),
    batch_size=32,
    shuffle=False,
    class_mode='categorical')

test_steps_per_epoch = math.ceil(test_generator.samples / test_generator.batch_size)
# Out:
# Found 525 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator, steps=test_steps_per_epoch)

predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = test_generator.class_indices.keys()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step

# %%
import os
from os import listdir
import pandas as pd

sehat = os.listdir("C:/Coding/pengujian/70-15-15/test/healthy")
septoria = os.listdir("C:/Coding/pengujian/70-15-15/test/septoria")
stripe_rust = os.listdir("C:/Coding/pengujian/70-15-15/test/stripe_rust")

data = sehat + septoria + stripe_rust

df = pd.DataFrame()
df['Nama File']=data
df['true_classes']=true_classes
df['Predicted_classes']=predicted_classes
df.to_csv('C:/Coding/pengujian/70-15-15/results/Hasil pengujian model SGD-40.csv')

# %% [markdown]
# # Find Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.figure(figsize=(10,7))
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  plt.yticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  #fmt = '.2f'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j]), horizontalalignment= "center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()

plt.savefig('C:/Coding/pengujian/70-15-15/results/Confusion Matrix Model SGD 70-15 epochs 40.png')
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix Klasifikasi Penyakit Daun Gandum')

# %% [markdown]
# # Find Performances Metrices

# %%
from sklearn import metrics
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
target_names = ['Healthy', 'Septoria', 'Stripe Rust']
report = metrics.classification_report(true_classes, predicted_classes, target_names=target_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.37      0.54       175
#     Septoria       0.63      0.98      0.77       175
#  Stripe Rust       0.92      1.00      0.96       175
#
#     accuracy                           0.78       525
#    macro avg       0.85      0.78      0.75       525
# weighted avg       0.85      0.78      0.75       525
