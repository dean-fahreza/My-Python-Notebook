# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Preprocessing Data

# %%
from keras_preprocessing.image import ImageDataGenerator

TRAINING_DIR = "train"
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

VALIDATION_DIR = "valid"
validation_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 180,
    shear_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

# %%
train_generator = training_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(256,256),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)
# Out:
# Found 2454 images belonging to 3 classes.
# Found 525 images belonging to 3 classes.

# %% [markdown]
# # Create Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
model = Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])
model.summary()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       6,423,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │           1,539 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,490,147 (24.76 MB)
#  Trainable params: 6,490,147 (24.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import optimizers

# Create the optimizer with the desired learning rate
opt = optimizers.Adam(learning_rate=0.001)

model.compile(loss = 'categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator, 
    epochs = 40,
    validation_data = validation_generator, 
    verbose = 1)
model.save("adam-40-model.h5")
# Out:
# Epoch 1/40
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.5368 - loss: 0.9481 - val_accuracy: 0.6324 - val_loss: 1.5660
# Epoch 2/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 79s 986ms/step - accuracy: 0.8761 - loss: 0.3491 - val_accuracy: 0.7448 - val_loss: 0.9512
# Epoch 3/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 947ms/step - accuracy: 0.9396 - loss: 0.1507 - val_accuracy: 0.7657 - val_loss: 0.8378
# Epoch 4/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 924ms/step - accuracy: 0.9663 - loss: 0.0863 - val_accuracy: 0.7562 - val_loss: 1.5105
# Epoch 5/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 77s 951ms/step - accuracy: 0.9781 - loss: 0.0666 - val_accuracy: 0.7390 - val_loss: 1.8744
# Epoch 6/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 73s 909ms/step - accuracy: 0.9656 - loss: 0.0887 - val_accuracy: 0.7105 - val_loss: 1.2375
# Epoch 7/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 78s 982ms/step - accuracy: 0.9834 - loss: 0.0492 - val_accuracy: 0.8610 - val_loss: 1.1153
# Epoch 8/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 946ms/step - accuracy: 0.9686 - loss: 0.0898 - val_accuracy: 0.7238 - val_loss: 1.4781
# Epoch 9/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 75s 936ms/step - accuracy: 0.9844 - loss: 0.0590 - val_accuracy: 0.7505 - val_loss: 1.3951
# Epoch 10/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 948ms/step - accuracy: 0.9835 - loss: 0.0542 - val_accuracy: 0.9219 - val_loss: 0.3898
# Epoch 11/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 73s 905ms/step - accuracy: 0.9812 - loss: 0.0453 - val_accuracy: 0.8648 - val_loss: 0.8174
# Epoch 12/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 75s 938ms/step - accuracy: 0.9757 - loss: 0.0605 - val_accuracy: 0.7562 - val_loss: 2.2222
# Epoch 13/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 921ms/step - accuracy: 0.9913 - loss: 0.0253 - val_accuracy: 0.7581 - val_loss: 1.3223
# Epoch 14/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 79s 967ms/step - accuracy: 0.9929 - loss: 0.0251 - val_accuracy: 0.7181 - val_loss: 1.2598
# Epoch 15/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 924ms/step - accuracy: 0.9807 - loss: 0.0632 - val_accuracy: 0.7581 - val_loss: 1.2914
# Epoch 16/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9971 - loss: 0.0108 - val_accuracy: 0.7752 - val_loss: 0.9162
# Epoch 17/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 956ms/step - accuracy: 0.9995 - loss: 0.0067 - val_accuracy: 0.8171 - val_loss: 0.7140
# Epoch 18/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 920ms/step - accuracy: 0.9997 - loss: 0.0033 - val_accuracy: 0.7581 - val_loss: 2.4545
# Epoch 19/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 70s 877ms/step - accuracy: 0.9990 - loss: 0.0053 - val_accuracy: 0.7619 - val_loss: 2.5849
# Epoch 20/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 70s 869ms/step - accuracy: 0.9823 - loss: 0.0637 - val_accuracy: 0.9105 - val_loss: 0.2797
# Epoch 21/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 70s 868ms/step - accuracy: 0.9576 - loss: 0.1184 - val_accuracy: 0.8933 - val_loss: 0.4076
# Epoch 22/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 70s 874ms/step - accuracy: 0.9935 - loss: 0.0198 - val_accuracy: 0.8857 - val_loss: 0.3916
# Epoch 23/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 70s 871ms/step - accuracy: 0.9977 - loss: 0.0065 - val_accuracy: 0.7619 - val_loss: 1.8019
# Epoch 24/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 71s 881ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.7619 - val_loss: 1.7449
# Epoch 25/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 67s 835ms/step - accuracy: 0.9851 - loss: 0.0612 - val_accuracy: 0.7981 - val_loss: 0.4791
# Epoch 26/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 67s 837ms/step - accuracy: 0.9961 - loss: 0.0111 - val_accuracy: 0.7867 - val_loss: 0.8096
# Epoch 27/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 67s 839ms/step - accuracy: 0.9960 - loss: 0.0154 - val_accuracy: 0.7810 - val_loss: 1.0424
# Epoch 28/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 67s 831ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.7733 - val_loss: 0.8412
# Epoch 29/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 64s 791ms/step - accuracy: 0.9995 - loss: 0.0068 - val_accuracy: 0.8324 - val_loss: 0.4574
# Epoch 30/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 929ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.7486 - val_loss: 1.0390
# Epoch 31/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9949 - loss: 0.0165 - val_accuracy: 0.8438 - val_loss: 0.5623
# Epoch 32/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 78s 971ms/step - accuracy: 0.9396 - loss: 0.2002 - val_accuracy: 0.7314 - val_loss: 1.3232
# Epoch 33/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 948ms/step - accuracy: 0.9805 - loss: 0.0720 - val_accuracy: 0.7752 - val_loss: 0.8118
# Epoch 34/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 919ms/step - accuracy: 0.9943 - loss: 0.0117 - val_accuracy: 0.7924 - val_loss: 0.9273
# Epoch 35/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 74s 921ms/step - accuracy: 0.9949 - loss: 0.0193 - val_accuracy: 0.7352 - val_loss: 2.6956
# Epoch 36/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 77s 960ms/step - accuracy: 0.9783 - loss: 0.0676 - val_accuracy: 0.7581 - val_loss: 0.9561
# Epoch 37/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 77s 955ms/step - accuracy: 0.9891 - loss: 0.0364 - val_accuracy: 0.9295 - val_loss: 0.4089
# Epoch 38/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 76s 951ms/step - accuracy: 0.9895 - loss: 0.0337 - val_accuracy: 0.7619 - val_loss: 0.7830
# Epoch 39/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 78s 973ms/step - accuracy: 0.9973 - loss: 0.0087 - val_accuracy: 0.9200 - val_loss: 0.5372
# Epoch 40/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 69s 859ms/step - accuracy: 0.9962 - loss: 0.0138 - val_accuracy: 0.7581 - val_loss: 1.4484
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, label='Akurasi Training')
plt.plot(epochs, val_acc, label='Akurasi Validation')
plt.title('Akurasi Training dan Validation Model 70:15 Adam epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/70-15-15/results/Hasil akurasi model Adam 70-15 epochs 40.jpg')
plt.figure()

plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss Training dan validation Model 70:15 Adam epochs 40')
plt.legend(loc=0)
plt.savefig('C:/Coding/pengujian/70-15-15/results/Hasil loss model Adam 70-15 epochs 40.jpg')
plt.figure()

plt.show()

# %% [markdown]
# # Testing Model

# %%
from tensorflow import keras
model = keras.models.load_model('C:/Coding/pengujian/70-15-15/adam-40-model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import math

TEST_DIR = "test"
test_datagen = ImageDataGenerator(
    rescale = 1.0/255
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(256,256),
    batch_size=32,
    shuffle=False,
    class_mode='categorical')

test_steps_per_epoch = math.ceil(test_generator.samples / test_generator.batch_size)
# Out:
# Found 525 images belonging to 3 classes.

# %%
predictions = model.predict(test_generator, steps=test_steps_per_epoch)

predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = test_generator.class_indices.keys()
# Out:
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step

# %%
import os
from os import listdir
import pandas as pd

sehat = os.listdir("C:/Coding/pengujian/70-15-15/test/healthy")
septoria = os.listdir("C:/Coding/pengujian/70-15-15/test/septoria")
stripe_rust = os.listdir("C:/Coding/pengujian/70-15-15/test/stripe_rust")

data = sehat + septoria + stripe_rust

df = pd.DataFrame()
df['Nama File']=data
df['true_classes']=true_classes
df['Predicted_classes']=predicted_classes
df.to_csv('C:/Coding/pengujian/70-15-15/results/Hasil pengujian model Adam-40.csv')

# %% [markdown]
# # Find Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
  plt.figure(figsize=(10,7))
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  plt.yticks(tick_marks, ['Healthy', 'Septoria', 'Stripe Rust'])
  #fmt = '.2f'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j]), horizontalalignment= "center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()

cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix Klasifikasi Penyakit Daun Gandum')

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('C:/Coding/pengujian/70-15-15/results/Confusion Matrix Model Adam 70-15 epochs 40.png', dpi=100)

# %% [markdown]
# # Find Performances Metrices

# %%
from sklearn import metrics
predicted_classes = np.argmax(predictions, axis=1)
true_classes = test_generator.classes
target_names = ['Healthy', 'Septoria', 'Stripe Rust']
report = metrics.classification_report(true_classes, predicted_classes, target_names=target_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       1.00      0.32      0.48       175
#     Septoria       0.63      0.61      0.62       175
#  Stripe Rust       0.59      1.00      0.74       175
#
#     accuracy                           0.64       525
#    macro avg       0.74      0.64      0.61       525
# weighted avg       0.74      0.64      0.61       525
